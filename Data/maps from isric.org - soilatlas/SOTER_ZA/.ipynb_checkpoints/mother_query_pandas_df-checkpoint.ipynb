# %%
import pandas as pd

# %% [markdown]
# # All Data

# %%
mother_q_path = 'mother_query_SOTER_ZA_18_03_2020_1656_adj_cols.xlsx'
data = pd.read_excel(mother_q_path)

# %%
data.head(5)
# Out:
#          PROF_ID  SOTER_ID  LNGI  LATI  ELEV DRAIN  SAND  SILT  CLAY  \
# 0  ZAV/4/20/CMca         1   NaN   NaN   NaN     W   NaN   NaN   NaN
# 1  ZAV/4/20/CMca         1   NaN   NaN   NaN     W   NaN   NaN   NaN
# 2  ZAV/4/20/CMca         1   NaN   NaN   NaN     W   NaN   NaN   NaN
# 3  ZAV/4/20/CMca         1   NaN   NaN   NaN     W   NaN   NaN   NaN
# 4  ZAV/4/20/LVcr         1   NaN   NaN   NaN     M   NaN   NaN   NaN
#
#    MOIST_FC  ...   K  AL  MIN_EL  MAX_EL  RELIEF_I  LANDFORM  LITHOLOGY  \
# 0       NaN  ... NaN NaN     481     563        12        LV        SC2
# 1       NaN  ... NaN NaN     481     563        12        LV        SC2
# 2       NaN  ... NaN NaN     481     563        12        LV        SC2
# 3       NaN  ... NaN NaN     481     563        12        LV        SC2
# 4       NaN  ... NaN NaN     481     563        12        LV        SC2
#
#    BEDROCK_DEPTH  VEGETATION  PROPORTION
# 0          1.089          II          10
# ...

# %%
data[6:12]
# Out:
#           PROF_ID  SOTER_ID      LNGI      LATI   ELEV DRAIN  SAND  SILT  \
# 6   ZAV/4/20/LVcr         1       NaN       NaN    NaN     M   NaN   NaN
# 7   ZAV/4/20/LVcr         1       NaN       NaN    NaN     M   NaN   NaN
# 8          ZA8470         2  29.92333 -22.29333  570.0     W  75.0  13.0
# 9          ZA8470         2  29.92333 -22.29333  570.0     W  73.0  10.0
# 10         ZA8470         2  29.92333 -22.29333  570.0     W   NaN   NaN
# 11  ZAV/4/14/CMro         2       NaN       NaN    NaN     W   NaN   NaN
#
#     CLAY  MOIST_FC  ...    K    AL  MIN_EL  MAX_EL  RELIEF_I  LANDFORM  \
# 6    NaN       NaN  ...  NaN   NaN     481     563        12        LV
# 7    NaN       NaN  ...  NaN   NaN     481     563        12        LV
# 8   12.0       5.0  ...  0.6  0.06     481     647        31        LV
# 9   17.0       7.0  ...  0.3  0.09     481     647        31        LV
# 10   NaN       NaN  ...  NaN   NaN     481     647        31        LV
# ...

# %%
data.describe()
# Out:
#            SOTER_ID         LNGI         LATI         ELEV         SAND  \
# count  37521.000000  4267.000000  4267.000000  4276.000000  3799.000000
# mean    1694.306015    26.905141   -28.405785  1010.146632    58.384838
# std      961.992745     3.584341     3.072390   465.058116    24.113723
# min        1.000000    16.566670   -34.256670    25.000000     2.000000
# 25%      868.000000    25.276670   -30.841390   700.000000    38.000000
# 50%     1675.000000    27.296670   -28.173330  1082.000000    61.000000
# 75%     2550.000000    29.770000   -25.801670  1350.000000    79.000000
# max     3281.000000    32.195000   -22.293330  2150.000000    99.000000
#
#               SILT         CLAY     MOIST_FC     MOIST_WP        ELCO  \
# count  3799.000000  3799.000000  3723.000000  3715.000000  551.000000
# mean     13.526981    26.721242    17.377652    10.767429    5.445608
# std      10.667740    18.207075    12.446975     8.365266   11.673860
# ...

# %% [markdown]
# # Reduced Data

# %%
reduced_data = data[['PROF_ID','SOTER_ID','MIN_EL','MAX_EL','RELIEF_I','LANDFORM','LITHOLOGY','BEDROCK_DEPTH','VEGETATION','PROPORTION']]
reduced_data.head(5)
# Out:
#          PROF_ID  SOTER_ID  MIN_EL  MAX_EL  RELIEF_I LANDFORM LITHOLOGY  \
# 0  ZAV/4/20/CMca         1     481     563        12       LV       SC2
# 1  ZAV/4/20/CMca         1     481     563        12       LV       SC2
# 2  ZAV/4/20/CMca         1     481     563        12       LV       SC2
# 3  ZAV/4/20/CMca         1     481     563        12       LV       SC2
# 4  ZAV/4/20/LVcr         1     481     563        12       LV       SC2
#
#    BEDROCK_DEPTH VEGETATION  PROPORTION
# 0          1.089         II          10
# 1          1.089       IIIB          43
# 2          1.089         II          10
# 3          1.089       IIIB          43
# 4          1.089         II          10

# %%
reduced_data.describe()
# Out:
#            SOTER_ID        MIN_EL        MAX_EL      RELIEF_I  BEDROCK_DEPTH  \
# count  37521.000000  37521.000000  37521.000000  37521.000000   37521.000000
# mean    1694.306015    824.150449   1166.974814     64.386210       0.556486
# std      961.992745    506.760128    549.021701     55.538125       0.284818
# min        1.000000      0.000000     16.000000      2.000000       0.000000
# 25%      868.000000    364.000000    759.000000     24.000000       0.342270
# 50%     1675.000000    923.000000   1263.000000     47.000000       0.515750
# 75%     2550.000000   1243.000000   1573.000000     86.000000       0.734570
# max     3281.000000   2346.000000   3286.000000    461.000000       1.320000
#
#          PROPORTION
# count  37521.000000
# mean      36.472909
# std       34.792743
# min        1.000000
# 25%        4.000000
# 50%       23.000000
# 75%       67.000000
# max      100.000000
