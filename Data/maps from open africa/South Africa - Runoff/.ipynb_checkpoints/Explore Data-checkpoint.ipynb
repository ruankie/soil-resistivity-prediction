# %% [markdown]
# # South Africa - Runoff

# %%
# import necessary packages
import os
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline

# %%
# read shapefile
sh_dir = 'RSA_runperc.shp'
polys = gpd.read_file(sh_dir)

# %%
polys.head(4)
# Out:
#    RUNOFFPERC                                           geometry
# 0        0.14  POLYGON ((29.35999 -22.19793, 29.36037 -22.197...
# 1        0.61  POLYGON ((28.51104 -22.58897, 28.51184 -22.588...
# 2        0.22  POLYGON ((30.12991 -22.31034, 30.12992 -22.310...
# 3        1.00  POLYGON ((30.76149 -22.30477, 30.76321 -22.304...

# %%
# view the spatial extent (like bounding box)
polys.total_bounds
# Out:
# array([ 16.45296263, -34.83360144,  32.89279807, -22.12583222])

# %%
# view data Coordinate Reference System (CRS) - projection of data
# epsg:32611 - WGS84
polys.crs
# Out:
# {'init': 'epsg:4148'}

# %%
# view geometry type of data (point, line, polygon)
polys.geom_type
# Out:
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 134    Polygon
# 135    Polygon
# 136    Polygon
# 137    Polygon
# 138    Polygon
# Length: 139, dtype: object

# %%
# view number of features in shapefile
polys.shape
# Out:
# (139, 2)

# %%
# basic plot - plot the data using geopandas .plot() method
fig, ax = plt.subplots(figsize = (15,15))
polys.plot(ax=ax,
           linewidth = 0.5,
           edgecolor='black',
           facecolor='lightgrey',
           alpha=0.9)
plt.show()

# %%
polys.columns
# Out:
# Index(['RUNOFFPERC', 'geometry'], dtype='object')

# %%
len(polys.RUNOFFPERC.unique())
# Out:
# 88

# %%
polys.RUNOFFPERC.unique()
# Out:
# array([0.14, 0.61, 0.22, 1.  , 0.29, 0.17, 0.73, 1.16, 0.93, 0.23, 1.31,
#        0.27, 0.05, 1.02, 0.76, 0.03, 1.41, 0.48, 0.19, 2.38, 0.32, 2.62,
#        0.49, 0.45, 1.48, 0.88, 4.55, 2.18, 1.79, 0.4 , 2.63, 0.21, 0.2 ,
#        0.33, 1.95, 1.03, 1.08, 1.87, 0.39, 0.6 , 3.12, 0.87, 2.7 , 0.  ,
#        9.53, 0.38, 0.77, 0.3 , 0.37, 0.68, 0.02, 1.42, 0.11, 2.09, 0.16,
#        0.46, 2.65, 0.01, 0.06, 5.44, 0.64, 0.81, 1.52, 0.55, 1.55, 0.13,
#        0.75, 0.18, 0.09, 0.92, 0.04, 0.12, 0.31, 0.91, 0.34, 0.62, 0.07,
#        0.1 , 0.41, 0.24, 0.44, 0.15, 0.08, 1.65, 0.85, 0.26, 0.36, 0.99])

# %%
print('min: ',np.min(polys.RUNOFFPERC))
print('max: ',np.max(polys.RUNOFFPERC))
print('mean: ',np.mean(polys.RUNOFFPERC))
print('mean(unique): ',np.mean(polys.RUNOFFPERC.unique()))
print('std: ',np.std(polys.RUNOFFPERC))
# Out:
# min:  0.0
# max:  9.53
# mean:  0.7114388489208634
# mean(unique):  0.9664772727272727
# std:  1.1352840491083387

# %%
fig, ax = plt.subplots(figsize = (15,15))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
polys.plot(ax=ax,
           column='RUNOFFPERC',
           linewidth = 0.3,
           edgecolor='black',
           legend=True,
           cax=cax,
           cmap='GnBu') # GnBu, YlGn, plasma, cividis
ax.set_title('South Africa - Runoff');

# %% [markdown]
# ### Multiple Coordinaltes

# %%
# find info at coordinates

#input coordinate
x = [29,25,17.5,30]
y = [-27,-32,-30,-24]
names = ['1','2','3','4']

df_dict = {'Name': names, 'x': x, 'y': y}
df_dict

df = pd.DataFrame.from_dict(df_dict)
inp_coords = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.x, df.y))
inp_coords
# Out:
#   Name     x   y                    geometry
# 0    1  29.0 -27  POINT (29.00000 -27.00000)
# 1    2  25.0 -32  POINT (25.00000 -32.00000)
# 2    3  17.5 -30  POINT (17.50000 -30.00000)
# 3    4  30.0 -24  POINT (30.00000 -24.00000)

# %%
# search for point in all polygons
return_polys_ind = []
answer_polys = gpd.GeoDataFrame()


for j in range(inp_coords.shape[0]):

    coord_geo = inp_coords.iloc[j].geometry

    for i in range(polys.shape[0]):
        if coord_geo.within(polys.iloc[i].geometry):
            return_polys_ind.append(i)

    answer_polys = answer_polys.append(polys.iloc[return_polys_ind[j]])
answer_polys
# Out:
#     RUNOFFPERC                                           geometry
# 27        2.18  POLYGON ((29.87223 -26.33303, 29.88099 -26.337...
# 82        0.04  POLYGON ((24.94300 -31.97755, 24.94191 -31.976...
# 60        0.01  POLYGON ((17.05188 -29.67809, 17.05334 -29.678...
# 7         1.16  POLYGON ((29.83511 -23.29855, 29.83703 -23.296...

# %%
out_dict = {'Name': inp_coords.Name.values,
            'x': inp_coords.x.values,
            'y': inp_coords.y.values,
            'RUNOFFPERC': answer_polys.RUNOFFPERC.values,
            'geometry': answer_polys.geometry.values}

final_out = pd.DataFrame(out_dict)
final_out
# Out:
#   Name     x   y  RUNOFFPERC  \
# 0    1  29.0 -27        2.18
# 1    2  25.0 -32        0.04
# 2    3  17.5 -30        0.01
# 3    4  30.0 -24        1.16
#
#                                             geometry
# 0  POLYGON ((29.87223 -26.33303, 29.88099 -26.337...
# 1  POLYGON ((24.94300 -31.97755, 24.94191 -31.976...
# 2  POLYGON ((17.05188 -29.67809, 17.05334 -29.678...
# 3  POLYGON ((29.83511 -23.29855, 29.83703 -23.296...

# %%
reduced_set = []
for col in polys.RUNOFFPERC.unique():
    if col is not None:
        if col !='*':
            reduced_set.append(col)

#reduced_set

# %%
# plot within SA
cols = ['b', 'g', 'r', 'c', 'm', 'y', 'pink', 'lightblue', 'pink', 'orange', 'lightgreen', 'darkgreen', 'lightgrey', 'darkblue', 'purple']
cols = cols*10

fig, ax = plt.subplots(figsize = (15,15))
leg_handles = []
transparency = 0.9

for i, item in enumerate(reduced_set):
    curr_set = polys[polys.RUNOFFPERC==item]
    curr_set.plot(ax=ax,
           linewidth = 0.5,
           edgecolor='black',
           #facecolor=cols[i],
           facecolor='lightgrey',
           alpha=transparency)
    #leg_handles.append(mpatches.Patch(color=cols[i], label=item, alpha=transparency))

#match_cond = polys.geometry[return_polys[0]]
#plot_poly = polys[polys.geometry==match_cond]
for i,geo in enumerate(answer_polys.geometry.unique()):
    curr_poly = answer_polys[answer_polys.geometry == geo]
    curr_poly.plot(ax=ax,
                   linewidth = 0.5,
                   edgecolor='black',
                   alpha=0.3,
                   facecolor=cols[i])#,
                   #hatch='//')
    leg_handles.append(mpatches.Patch(color=cols[i], label=final_out.RUNOFFPERC[i], alpha=0.3))

for i,coor in enumerate(inp_coords.geometry.unique()):
    curr_coor = inp_coords[inp_coords.geometry == coor]
    curr_coor.plot(ax=ax, color=cols[i], linewidth = 1, edgecolor='black', marker='o', markersize=80)
    leg_handles.append(mlines.Line2D([], [],color=cols[i], linewidth = 1, marker='o',linestyle='None', label=inp_coords.Name[i]+': '+str(final_out.RUNOFFPERC[i])))

# other details
plt.legend(handles=leg_handles, loc='upper left')
ax.set_title('Coordinates Summary - Runoff', fontsize=20)
ax.grid(color='grey',linestyle='-', linewidth=0.5, alpha=0.4)
#ax.set_axis_off()    # turn off the x and y axis
#plt.axis('equal')    # ensure the x and y axis are uniformly spaced
plt.show()

# %%
final_out[['Name','x','y','RUNOFFPERC']]
# Out:
#   Name     x   y  RUNOFFPERC
# 0    1  29.0 -27        2.18
# 1    2  25.0 -32        0.04
# 2    3  17.5 -30        0.01
# 3    4  30.0 -24        1.16
